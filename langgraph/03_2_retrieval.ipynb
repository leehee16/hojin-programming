# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1500,
    chunk_overlap = 100,
    separators= ['\n\n', '\n']
)

# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader

loader = UnstructuredMarkdownLoader(
    "./data/income_tax.md",
    mode="single",
    strategy="fast",
)
docs = loader.load_and_split(text_splitter)
docs

# %%
# md to txt for table
import markdown
from bs4 import BeautifulSoup

with open('./data/income_tax.md', 'r', encoding='utf-8') as md_file:
    md_content = md_file.read()

html_content = markdown.markdown(md_content)
soup = BeautifulSoup(html_content, 'html.parser')
text_content = soup.get_text()

with open('./data/income_tax.txt', 'w', encoding= 'utf-8') as txt_file:
    txt_file.write(text_content)

# %%
from langchain_community.document_loaders import TextLoader
txt_loader = TextLoader(
    './data/income_tax.txt',
    encoding = 'utf-8'
)
txt_docs = txt_loader.load_and_split(text_splitter)
txt_docs[:5]
# Out:
# [Document(metadata={'source': './data/income_tax.txt'}, page_content='소득세법\n[시행 2025. 10. 1.] [법률 제21655호, 2025. 10. 1., 타법개정]\n기획재정부 (세제실세제과) 044-215-4312\n기획재정부 (소득세제과) 044-215-4216\n기획재정부 (금융세제과) 044-215-4233\n기획재정부 (소득세제과(사업소득, 기타소득)) 044-215-4217  \n제1장 총칙\n제조(목적)\n이 법은 개인의 소득에 대하여 소득의 성격과 납세자의 부담능력 등에 따라 적정하게 과세함으로써 재정수입의 원활한 조달에 이바지함을 목적으로 한다.\n[본조신설 2009. 12. 31.]\n[종전 제1조는 제2조로 이동 2009. 12. 31.]\n제2조(정의)\n이 법에서 사용하는 용어의 뜻은 다음과 같다. [개정 2010. 12. 27, 2014. 12. 23, 2018. 12. 31.]\n\n“거주자”란 국내에 주소를 두거나 183일 이상 거소(居所)를 둔 개인을 말한다.\n“비거주자”란 거주자가 아닌 개인을 말한다.\n“내국법인”이란 법인세법 제2조제1호에 따른 내국법인을 말한다.\n“외국법인”이란 법인세법 제2조제3호에 따른 외국법인을 말한다.\n“사업자”란 사업소득이 있는 거주자를 말한다.\n제5항에 따른 사업자·소득자·비거주자의 구분은 대통령령으로 정한다.\n[본조신설 2009. 12. 31.]\n\n제2조(납세의무)\n구분리스트.\n\n거주자\n비거주자로서 국내원천소득(國內源泉所得)이 있는 개인\n다음 각 호의 어느 하나에 해당하는 자는 이 법에 따라 원천징수한 소득세를 납부할 의무를 진다.\n거주자\n비거주자\n내국법인\n외국법인및 국내사업장 또는 국내영업소(출처소, 그 밖에 이에 준하는 것을 포함한다. 이하 같다)\n그 밖에 법에서 정하는 원천징수의무자\n“국세기본법” 제23조제1항에 따른 법인이 아닌 단체 같은 제2항에 따른 법인이 보는 단체로서 “법인은 법인 외의 법인 아닌 단체는 국내에 주사무소 또는 사업의 실질적 관리장소로서 거주자로 보는 단체”를 한다) 외의 법인 아닌 단체는 국내에 주사무소 또는 사업의 실질적 관리장소로서 거주제로 본다. 다음 각 호의 어느 하나에 해당하는 경우에는 소득을 납부할 의무를 진다. “법인세법”에 따른 소득세는 법인에 본법에서 규정한 무를 진다.\n[개정 2010. 12. 27, 2013. 1. 1, 2018. 12. 31.]\n\n제3조(구성원에 대한 세법의 적용)\n구성원은 이하의 개인에 의하여 정하여져 있고 해당 구성원별 연명의 분배비율을 확인하는 경우\n구성원에 의하여 정해졌으나 아니라 사적인 구성원별 일반 분배비율로 정해지는 경우\n제3항에도 불가항에 해당 단체의 전체 구성원 중 해당 구성원의 분배비율을 확인되지 않을 경우에 대해 다음 각 호에 따른 소득세 또는 법인세를 납부할 의무를 진다.\n[신설 2018. 12. 31.]\n법제처 1\n소통세븐'),
#  Document(metadata={'source': './data/income_tax.txt'}, page_content='확인되는 부분: 해당 구성원별로 소득세 또는 법인세에 대한 납세의무 부담  \n확인되지 아닌하는 부분: 해당 단체를 가리켜서 또는 비영리법인으로 보는 단체에 대한 납세의무 부담\n   (제3조 및 제4조에도 불구하고 법인은 보되 단체 외의 법인이 아닌 단체에 해당하는 회의자권을 하여 모든 금지 등의 가치를 가지고 있는 투자자산을 취득, 분할하는 데 밖의 방법으로 운영하고 그 결과를 투자자에게 배분하기 위하여 귀속시키는 투자행위를 하는 기로를 말한다. 아래 각 담별로 제119조의2에 제정하듯이 한국원천소득의 실질귀속자로 보는 그 국외법인자에게 소득세를 납부할 의무가 진다. <시산 2018. 12. 31.>\n   [전문개정 2009. 12. 31.]\n   [제1조에서 이동, 중간 제2조는 제2조로 이동 <2009. 12. 31.>]'),
#  Document(metadata={'source': './data/income_tax.txt'}, page_content='제22조(단세무의무의 범위)\n① 제43조에 따라 공통사업에 관한 소득세를 계산하는 경우에는 해당 공통사업자별로 납세의무를 진다. 다만, 제43조제3항에 따른 주된 공통사업자(이하에 "주된 공통사업자"라 한다)에 합산과세되는 경우 함산대상에서 소득금액에 대해서는 주된 공통사업자와 특수관계에 있는 자로서 제진한 바에는 손인별반에 해당되는 그의 소득금액을 한도로 주된 공통사업자와 면세의무를 진다. <개정 2012. 1. 1., 2013. 1. 1.>\n② 제44조에 따라 피상속인의 소득금액에 대해서는 그 상속인의 비세의무를 진다.\n제110조제3항에 따라 증여자 가상가가 사실을 직적 용도로 보는 경우 그 양도소득에 대해서는 증여받은 중여반도자로 여기에 대한 비세의무를 진다. <개정 2020. 12. 29.>\n③ 제127조에 따라 완전종합되는 소득으로 제14조제13항 또는 다른 방법에 따라 제14조제2항에 따른 소득과세에 합산되지 아니하는 소득이 있는 경우에는 이 원천징수는 소득세에 대한 세의의무를 진다. <개정 2020. 12. 29.>\n제23조(신탁재산 귀속 소득에 대한 납세의무의 범위)\n① 신탁재산에 귀속되는 소득은 그 신탁이의를 받을 수익자(수익자가 사용하는 경우에는 이 상속인에게 귀속되는 것으로 본다.\n② 제18항에 불구하고 위탁자가 신탁재산을 실질적으로 통해든 등 대동행위로 정하는 요건을 충족하는 신탁의 경우에는 그 신탁액에 귀속되는 소득은 위탁자에게 귀속되는 것으로 본다.<개정 2023. 12. 31.>\n[본소신 2022. 12. 29.]\n제32조(과세소득의 범위)\n거주자에게는 이 법에 의해 정하는 모든 소득에 대해서 과세된다. 다만, 특별히 과세되지 중요 서명 연령부터 국내에 주소한지 튼 기간의 합계가 5년 이상의 외국인 거주자로이에게 과세되는 소득은 국외법에 발생된 소득의 경우 국내에서 지급되는 국민소득에 대해서만 과세한다.\n비과세규정에는 제119조에 따라 한국원천소득에 대해서만 과세한다.\n제18항 및 제2항을 적용하는 경우 "조세특례제한법" 제100조제14제2항에 의거한 제100조제18제1항에 따라 배분받은 소득 및 같은 법 제100조제22제1항에 따라 분배받은 자산 중 분배법인에 지분을 초과하여 발생하는 소득에 대하여 과세한다.\n[전문개정 2009. 12. 31.]\n제40조(소득의 구분)\n\n종합소득\n   이 법에 따라 규정되는 모든 소득에 제2조 및 제3조에 따른 소득으로 제외된 소득으로 다음 각 목의 소득을 포함한 것  \n\n소득세법\n가. 이자소득\n나. 배당소득\n다. 사업소득\n라. 근로소득\n마. 영업소득\n바. 기타소득'),
#  Document(metadata={'source': './data/income_tax.txt'}, page_content="소득세법\n가. 이자소득\n나. 배당소득\n다. 사업소득\n라. 근로소득\n마. 영업소득\n바. 기타소득  \n\n퇴직소득\n2의2. 삭제 <2024. 12. 31.>  \n양도소득\n② 제1항에 따른 소득을 규급할 때 다음 각 호의 신탁의 이익은 「신탁법」 제2조에 따른 수탁자에게 이전하거나 그 밖에 처분된 재산권에서 발생하는 소득의 내용별로 구분한다. <개정 2011. 7. 25, 2020. 12. 29, 2022. 12. 31, 2024. 12. 31.>  \n'합성재산' 제305조제2항에 따라 신탁재산에 귀속되는 소득에 대하여 그 신탁의 수탁자가 법인설비를 납부하는 신탁  \n'자본시장과 금융투자업에 관한 법률', 제90조제1항제1호에 따른 투자신탁(제17조제1항제5호에 따른 집합투자기구 포함)한다  \n'자본시장과 금융투자업에 관한 법률', 제251조제1항에 따른 집합투자업영업보험회사의 특별계정  \n제7조제1항제3호의에 따른 수익증권이 발행된 신탁  \n비거주자의 소득은 제19조에 따라 구분한다.\n[전문개정 2009. 12. 31.]"),
#  Document(metadata={'source': './data/income_tax.txt'}, page_content='제2조(과세기간)\n① 소득세의 과세기간은 1월 1일부터 12월 31일까지 1년으로 한다.\n② 거주자가 사업의 세대기간이 1월 1일부터 시작한다.\n③ 거주자가 주소 또는 거소를 국외로 이전(이하 "출국"이라 한다)하거나 비거주자가 되는 경우 세대기간은 1월 1일부터 축출한 날짜부터 한다.\n[전문개정 2009. 12. 31.]\n제3조(납세지)\n① 거주자의 소득세 납세지는 그 주소지로 한다. 다만, 주소지가 없는 경우에는 그 거소지로 한다.\n② 비거주자의 소득세 납세지는 제120조에 따른 국내사업장(이하 "국내사업장"이라 한다)의 소재지로 한다. 다만, 국내사업장이 있을 경우에 주된 국내사업장의 소재지로 하고, 국내사업장이 없는 경우에는 국외납세지에 해당하는 장소로 한다. <개정 2015. 1. 1.>\n③ 납세지가 불분명한 경우에는 대통령령으로 정하는 바에 따라 납세지를 결정한다.\n[전문개정 2009. 12. 31.]\n제4조(원천징수 등의 납세지)\n① 원천징수하는 소득세의 납세지는 다음 각 호에 따라 한다. <개정 2012. 1. 1, 2023. 12. 31.>\n1. 원천징수하는 자가 거주자인 경우: 그 비거주자 주된 사업장이지만, 주된 사업장 외의 사업장이 외출에 현징 수를 하는 경우에는 그 사업장의 소재지, 사업장이 없는 경우에는 거주자의 주소지 또는 거소지로 한다.\n2. 원천징수하는 자가 비거주자인 경우: 그 비거주자 주된 국내사업장의 소재지. 다만, 주된 국내사업장이 없는 경우에는 비거주자가 개취방(鑄熔) 또는 제4호로 한다.\n원천징수하는 자가 법인이거나 그 법인의 본점 또는 주사무소의 소재지\n4. 원천징수하는 자가 권리서로서 법인인 경우: 제3조에 따라 주상자의 소재지가 국외에 있는 경우로 제정한다. 다만, 특별범죄로 정하는 경우에는 그 법인의 본점 또는 주사무소의 소재지로 소득세 원\n천재지변에 의한 난시로 할 수 있다. \n5. 제156조, 제156조의2부터 제156조의6까지 및 제156조의9에 따른 원전징수의무자 제제호부터 제4호까지의 규정에서 정하는 난시제를 가지지 아니한 경우, ㅇㅇㅇㅇ 대행룡법을 정하는 난시제로 한다. 난시제합이 제150조에 따라 정하는 소득세의 난시제는 그 난시제합의 소지체로 한다. [전문개정 2009. 12. 31.]\n제8조(상속 동의 경우 신고)')]

# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv
load_dotenv()

embeddings = OpenAIEmbeddings(model = "text-embedding-3-small")

# %%
from langchain_chroma import Chroma

vector_store = Chroma.from_documents(
    txt_docs,
    embeddings,
    collection_name='income_tax_collection',
    persist_directory='./data/income_tax_collection'
)

# %%
retriever = vector_store.as_retriever()

# %%
query = '피고용보험 가입자의 소득세는?'
retriever.invoke(query)
# Out:
# [Document(id='8dd27fc1-9e2b-4f48-a54d-184b9ef7f003', metadata={'source': './data/income_tax.txt'}, page_content='위와 같은 경우에 제세액과 별도로 평균화 구간 명칭, 전환형의 100분의 10을 300만원(전환 세액기준에 해당 납입한 경우에는 300만원에 기초 납입액이 적용되는 금액을 차감한 금액으로 한다) 그 목적 금액과 제척 장 조세를 통해 연금계좌의 납입한 금액으로 하는 금액을 제정부서 제58행정이 규정에 따라 연금계좌세액정산 및 신청 적절 등 관리에 필요한 사항은 대동 범위로 한다. <개정 2019. 12. 31.>\n[분조신설 2014. 1. 1.]\n제59조(특별세액공제) ① 근로소득이 있는 거주자(일용근로자는 제외한다. 이하 이 조에서 같다)가 해당 과세기간에 만기와 환급되는 금액에 납입보험료를 초과하지 아니하는 보험의 보험혜택에 따라 지급받는 다음 각 호의 보험료를 지출세액에서 공제한다. 다만, 다음 각 호의 보험료로 각 과세기간에 각각 100만 원을 초과하는 경우 그 초과하는 금액은 각락 있는 것으로 한다. <개정 2015. 5. 13.>'),
#  Document(id='8af133e6-67c1-4cdf-a775-b5bdd6a69cda', metadata={'source': './data/income_tax.txt'}, page_content='기초공제대상자 중 장애인인 피부양자 또는 수급자 하는 장애인전용보험으로서 지급하는 보험료\n기초공제대상자를 피부법자로 하는 대출형량으로 정하는 보험료(제1호에 따른 장애인전용장애보험으로 제정한다)\n\n② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한 다를) 위하여 해당 과세기간에 대 통합적으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 15/제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30에 해당하는 금액을 해당 과세기간의 종합소득세에서 공제한다. <개정 2014. 12. 23., 2016. 12. 20., 2017. 12. 19., 2021. 12. 8., 2023. 12. 31.>\n\n기초공제대상자를 위하여 지급한 의료비(제20조부터 제34조까지의 의료비 제외한다)로 총금액에 100분의 3을 곱하여 계산한 금액을 초과하는 금액. 다만, 그 금액이 700만 원을 초과하는 경우에는 700만 원을 한 금액.\n다음 각 목의 어느 하나에 해당하는 사람을 위하여 지급한 의료비. 단, 제1호의 의료비가 종합소득세에 100분의 3을 곱하여 계산한 금액에 미달하는 경우에는 그 미달하는 금액을 뺀다.\n가. 해마다 거주인\n나. 세계질병 계시인 현재 6세 이하의 사람\n다. 과세제2종류로 현재 65세 이상인 사람\n라. 장애인\n마. 대출형량으로 정하는 중증질환자, 희귀난치성질환자 또는 결핵환자\n대출형량으로 정하는 미각이 뛰어난 선택신상에 대하여 지급한 의료비. 단, 제1호 및 제2호의 의료비 합계액이 총금액에 100분의 3을 곱하여 계산한 금액에 미달하는 경우에는 그 미달하는 금액을 뺀다.\n대출형량으로 정하는 난임시술(이하 “난임시술”이라 한다)을 위하여 지급한 비용(난임시술 관련하여 처방을 받은 자 포함). 제20조에 따른 의무를 구입을 포함한다. 단, 제1호 및 제3호의 의료비 합계액이 총금액에 100분의 3을 곱하여 계산한 금액에 미달하는 경우에는 그 미달하는 금액을 뺀다.\n③ 근로소득이 있는 거주자가 그 과세기간에 대한 과세의 기준에 대하여 생계가 최저임금에 미달하는 동안에 대해서는 세계지급률은 현재 18세 미만이나 해당하는 경우에는 기초공제대상으로 하는 학자금 대출을 받을 경우에는 제어하는 소득세를 제상의 제적여기, 대출형과 관련하여 지급하는 교부비를 포함한다. 만, 재단이 설립이후 제2항을 1명당 900만 원, 초등학교 취학 전 아동과 초·중·고등학생의 경우에는 18명당 300만 원을 반환한다.  \n\n따라 원격대학 형태의 평생교육시설(이하 "원격대학"이라 한다)'),
#  Document(id='eae80bd4-19e7-44c5-93ae-3ef33f6ffdfc', metadata={'source': './data/income_tax.txt'}, page_content='제121조(비거주자에 대한 과세범) 비거주자에 대하여 과세하는 소득세는 국내원천소득을 종합하여 과세하나 경우와 부득이하게 과세하는 경우 및 국외법인소득을 분리하여 과세하는 경우를 제외하고 계산한다.<개정 2013. 1. 1.>\n국 내 사업장에 있는 비거주자와 제119조 제3호에 따라 국내원천 세부상속이 있는 비거주자에 대해서는 제119조 제2항부터 제7호의 제8호부터 제12부의 소득(제156조 제13항 및 제156조 제3항부터 선옥점 경) 일컫는 판별기준으로 한다. \n156조의6가찌의 규정에 따라 원천징수되는 소득은 제외한다, 제119조제8호에 따른 국내원천퇴직소득 및 같은 조 제호에 따른 국내원천 부동산소득의 소득이 있는 비거주자에 대해서는 거주자와 같은 방법으로 보고하며 설명한다.  다만, 제119조제9항에 따른 국내원천 부동산소득이 있는 비거주자로서 대책법령으로 정하는 비거주자에 대해서는 제109조제1항제3호·제4호 및 제109조제2항과 관련된 부분 단서에 적용하지 아니한다.<개정 2012. 1. 1, 2013. 1. 1, 2018. 12. 31, 2019. 12. 31.>\n1)  국내사업장이 없는 비거주자에 대해서는 제119조 제3항 (제호는 제119조는 제외한다)에 대해 과세한다.<개정 2013. 1. 1.>\n가)  국내사업장이 있는 비거주자의 국내원천소득으로서 제156조제1항 및 제156조제3항부터 제156조제6까지의 규정에 따라 원천징수되는 소득에 대해서는 제119조 각 호(제1호 및 제2호는 제외한다)의 소득법에 과세한다.<개정 2012. 1. 1, 2013. 1. 1.>\n2)  제3항 및 제4항에 따라 과세되는 경우로서 원천징수되는 소득 중 제119조제6호에 따른 국내원천 인적용역소득이 있는 비거주자 자의 소득에 대해서 종합소득과세표준을 확정시키는 경우에는 제119조 각 호(제1호 및 제9호는 제119조의)의 소득에 대하여 종합소득세 과세를 할 수 있다.<개정 2013. 1. 1, 2018. 12. 31.>\n3)  국내사업장이 있는 비거주자가 공동으로 사업을 경영하고 그 손익을 분배하는 공동사업의 경우 원천징수된 세액에 대해서는 제109조를 준용한다.<신설 2009. 12. 31.>\n제2편 비거주자에 대한 종합소득세\n제122조(비거주자 통합과세 시 과세표준과 세액의 계산) \n제121조제1항 또는 제123조에서 규정하는 비거주자의 소득에 대한 소득세의 과세표준과 세액의 계산에 관하여는 이 법 중 거주자에 대한 소득세의 과세표준과 세액에 관한 규정을 준용한다.  다만, 제125조제3항에 따른 신청제외 중 비거주자 본인이 외국에 대한 설명과 제205조에 따른 특별소득으로제, 제109조256의이며 제119조제4호에 따른 특별세액공제를 하지 아니한다.<개정 2018. 12. 31.>\n제123조(삭제)<2013. 1. 1.>\n제124조(비거주자의 신고 의무)'),
#  Document(id='e6b109d6-664f-40b7-96e4-c289193c4d72', metadata={'source': './data/income_tax.txt'}, page_content='[전문규정 2009. 12. 31.]\n제27조(사업소득의 필요경비) 사업소득금액을 계산할 때 필요경비에 산입할 금액은 해당 과세기간의 총수입금액에 해당하는 내용으로서 일반적으로 용인되는 통상적인 것에 한계적으로 한다. <개정 2010. 12. 27.>\n소 특 세 번\n② 해당 과세기간 전의 총수입금액에 대응하는 비용으로서 그 과세기간에 확정된 것에 대해서는 그 과세기간 전의 필요경비를 계산하지 아니한 것과 그 과세기간의 필요경비로 본다.\n[전문개정 2009. 12. 31.]\n[제목개정 2010. 12. 27.]\n제28조(대손충당금의 필요경비 계산) ① 사업자가 외상매출금, 미수금, 그 밖에 이에 준하는 채권에 대한 대손충당금을 필요경비로 계상한 경우에는 대통령령으로 정하는 범위에서 이를 해당 과세기간의 소득금액을 계산할 때 필요경비에 산입한다.\n② 제1항에 따라 필요경비에 산입한 대손충당금의 잔액은 다음 과세기간의 소득금액을 계산할 때 총수입금액에 산입한다.\n③ 대손충당금의 처리는 대통령령으로 정한다.\n[전문개정 2009. 12. 31.]\n제29조(퇴직급여충당금의 필요경비 계산) ① 사업자가 종업원의 퇴직급여에 충당하기 위하여 퇴직급여충당금을 필요경비로 계상한 경우에는 대통령령으로 정하는 범위에서 이를 해당 과세기간의 소득금액을 계산할 때 필요경비에 산입한다.\n② 퇴직급여충당금의 처리는 대통령령으로 정한다.\n[전문개정 2009. 12. 31.]\n제30조 삭제 1998. 10. 5.\n제31조(분활화의무로 취득한 자산가액의 필요경비 계산) ① 사업자가 유상자산의 매입 또는 파손으로 인하여 보존범위 지긋한 유휴자산을 대체하여 같은 종류의 자산을 취득하거나 대체 취득한 자산 또는 파손된 유휴자산을 개발하는 경우에는 해당 자산의 가격 중 자산의 취득 또는 개량하는데 사용된 보험직의 상당액을 대통령령으로 정하는 범위 내에 따라 보혐금 받은 날이 속하는 과세기간의 소득금액을 계산할 때 필요경비에 산입할 수 있다. <개정 2019. 12. 31.>\n② 보혐금을 받은 날이 속하는 과세기간에 제18조에 따라 해당 자산을 취득하거나 개발할 수 있는 경우에는 그 과세기간의 다음 과세기간 개시일부터 2년 이내에 자산을 취득 또는 개량하는 것에 해당함을 증명한다.\n③ 제28조에 따라 보혘가 상당액에 산입한 자산과 다음 각 호의 어느 하나에 해당하는 보험직의 상당액을 사업자가 보존하는 과세기간의 총수입금액에 산입한다. <개정 2019. 12. 31.>\n1. 보혘이 사용된 자산을 취득 또는 개량하기 위해 기관급이 사용되지 아니한 경우\n2. 제12조를 적용하여 사용하는 경우\n[전문개정 2009. 12. 31.]\n[제목개정 2019. 12. 31.]')]

# %%
from langchain_core.documents import Document
from typing_extensions import List, TypedDict

class AgentState(TypedDict):
    query: str
    context: List[Document]
    answer: str

# %%
from langgraph.graph import StateGraph
graph_builder = StateGraph(AgentState)

# %%
def retrieve(state: AgentState):
    query = state['query']
    docs = retriever.invoke(query)
    return {'context': docs}

# %%
#같이 담아줄 프롬프트 랭스미스
from langsmith import Client
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-4o')
client = Client()
prompt = client.pull_prompt("rlm/rag-prompt")

# %%
def generate(state: AgentState):
    query = state['query']
    context = state['context']
    rag_chain = prompt|llm
    response = rag_chain.invoke({'question':query, 'context':context})
    return {'answer':response}

# %%
from langgraph.graph import START, END

graph_builder.add_node('retrieve',retrieve)
graph_builder.add_node('generate',generate)


graph_builder.add_edge(START, 'retrieve')
graph_builder.add_edge('retrieve', 'generate')
graph_builder.add_edge('generate', END)

# %%
graph = graph_builder.compile()

# %%
sequence_graph_builder = StateGraph(AgentState).add_sequence([retrieve,generate])

# %%
sequence_graph_builder.add_edge(START, 'retrieve')
sequence_graph_builder.add_edge('generate', END)

# %%
query = '소득세법에서 정의하는 종합소득의 종류는 무엇인가?'
initial_state = {'query': query}
graph.invoke(initial_state)
# Out:
# {'query': '소득세법에서 정의하는 종합소득의 종류는 무엇인가?',
#  'context': [Document(id='247ccd0d-0f9f-4f49-9050-a20ee5811a00', metadata={'source': './data/income_tax.txt'}, page_content='종합소득에 대한 과세표준(이하 “종합소득과세표준”이라 한다)은 제16조, 제17조, 제19조, 제20조, 제21조, 제22조부터 제26조까지, \n제27조부터 제29조까지, 제31조부터 제35조까지, 제37조, 제39조, 제41조부터 제46조까지, 제46조의2, 제47조에 따라 제47조의2에 따른 이자소득금, 배당소득금, 사업소득금, 근로소득금, 액면금소득 및 기타소득의 합계액(이하 “종합소득금액”이라 한다)은 다음의 비율로 제50조, 제51조, 제51조의2에 따른 총량에 따라 “종합소득공제”를 적용하고 한다. <개정 2013. 1. 1. , 2014. 1. 1.>\n당 정각 혀에 따른 소득의 종합소득과세표준을 계산할 때 한산하지 아니다.<개정 2010. 12. 27., 2011. 7. 14., 2013. 1. 1., 2014. 12. 23., 2015. 12. 15., 2017. 12. 19., 2018. 12. 1., 2019. 12. 31., 2020. 12. 29. , 2023. 12. 1.>'),
#   Document(id='731ac11c-5549-4caa-b2c1-0bf68c1ef0c7', metadata={'source': './data/income_tax.txt'}, page_content='제64조의3(분리과세기타소득에 대한 세액 계산의 특례)\n제14조에 따라 종합소득과세표준을 계산할 때 제127조제1항제 1항제6호나목의 소득을 합산하지 아니하는 경우 그 합산하지 아니하는 기타소득에 대한 계산세액은 해당 기타소득 금액에 제120조제1항제6호의 세율을 적용하여 계산한 금액으로 한다.<개정 2020. 12. 29.> \n1) 제180조의4의4의 소득을 합산하지 아니하는 경우 그 합산하지 아니하는 기타소득에 대한 계산세액은 해당 기타소득금액에 제129조제1항제6호의 세율을 적용하여 계산한 금액으로 한다.<개정 2020. 12. 29.> \n가. 제202조의3제1항제2호 및 제3호에 따른 연금소득 중 분리과세연금소득 외의 연금소득 등 100분의 15를 차감하여 산출한 금액\n나. 가각의 종합소득 결정세액\n[본조신설 2022. 12. 31.]\n제67조 증여세 - 예고신고 및 세액 납부\n<개정 2009. 12. 31.> \n제1항 증여안내 <개정 2009. 12. 31.> \n제65조(종합소득)\n① 납세지 관할 세무서장은 종합소득이 있는 거주자(대통령령으로 정하는 소득인이 있는 자)의 해동 과세기간 개시일 현재 사업자가 아닌 자로서 그 과세기간 중 신고로 사업을 시작하는 자를 제외한다. 이하 이 조에서 “특례법”이란 “중간세법시행규칙”이라 한다) 본인이 1회 해당하는 금액이란 “종합소득세액”이라 하며, 1천만 원 미만인 단수 있을 때에는 단수금액은 반납하여야 하며 세액으로 결정하여 11월 30일까 지 그 세액을 신고하여 한다. 이 경우 납세지 관할 세무서장은 중간세법의 납부고지서를 발행하여야 한다. <개정 2013. 1. 1., 2020. 12. 29.>\n② 제정에 따라 고지된 중간세액을 납부하여야 할 거주자가 11월 30일까지 그 세액의 전부 또는 일부를 납부하지 아니한 경우에는 납부하지 아니한 세액 제7조에 따라 환불받을 수 있는 세액에 대하여 납부의 지간 없었던 것으로 보며, 납세지 관할 세무서장은 해당 세기간이 다음의 연도 1월 1일부터 1월 15일까지의 기간이 그분납변보낼 수 있는 세액을 납부세율로 하는 납부고지서를 발행하여야 한다. <개정 2012. 1. 1., 2020. 12. 29.>\n③ 종합소득이 있는 거주자와 중간세기간이 중요한 제중간세기간 중간소득금액에 대한 소득세액(이하 “중간세법시행규칙”이라 한다)의 중간세법중점에서 100본 30에 미달하는 경우에는 11월 1일부터 11월 30일까지의 기간이 대통령령으로 정하는 바에 따라 중간세벌세액으로 하여 납세지 관할 세무서에 신고할 수 있다.\n④ 제3항에 따라 종합소득이 있는 거주자가 신고를 한 경우에는 제1항에 따른 중간세법의 결정이 없었던 것으로 해석한다.\n⑤ 종합세부세표에서는 제116조제3항에 따라 복식부기의무자와 해당 과세기간에 중간세법이 중 소득이 있는 경우에는 11월 1일부터 11월 30일까지의 기간이 대통령령으로 정하는 바에 따라 중간세법세액을 하여 납세지 관할 세무서에 신고하여야 한다. <개정 2018. 12. 31.>'),
#   Document(id='8e5b8250-a70d-43cd-919c-59c979ec4fee', metadata={'source': './data/income_tax.txt'}, page_content='제22조(단세무의무의 범위)\n① 제43조에 따라 공통사업에 관한 소득세를 계산하는 경우에는 해당 공통사업자별로 납세의무를 진다. 다만, 제43조제3항에 따른 주된 공통사업자(이하에 "주된 공통사업자"라 한다)에 합산과세되는 경우 함산대상에서 소득금액에 대해서는 주된 공통사업자와 특수관계에 있는 자로서 제진한 바에는 손인별반에 해당되는 그의 소득금액을 한도로 주된 공통사업자와 면세의무를 진다. <개정 2012. 1. 1., 2013. 1. 1.>\n② 제44조에 따라 피상속인의 소득금액에 대해서는 그 상속인의 비세의무를 진다.\n제110조제3항에 따라 증여자 가상가가 사실을 직적 용도로 보는 경우 그 양도소득에 대해서는 증여받은 중여반도자로 여기에 대한 비세의무를 진다. <개정 2020. 12. 29.>\n③ 제127조에 따라 완전종합되는 소득으로 제14조제13항 또는 다른 방법에 따라 제14조제2항에 따른 소득과세에 합산되지 아니하는 소득이 있는 경우에는 이 원천징수는 소득세에 대한 세의의무를 진다. <개정 2020. 12. 29.>\n제23조(신탁재산 귀속 소득에 대한 납세의무의 범위)\n① 신탁재산에 귀속되는 소득은 그 신탁이의를 받을 수익자(수익자가 사용하는 경우에는 이 상속인에게 귀속되는 것으로 본다.\n② 제18항에 불구하고 위탁자가 신탁재산을 실질적으로 통해든 등 대동행위로 정하는 요건을 충족하는 신탁의 경우에는 그 신탁액에 귀속되는 소득은 위탁자에게 귀속되는 것으로 본다.<개정 2023. 12. 31.>\n[본소신 2022. 12. 29.]\n제32조(과세소득의 범위)\n거주자에게는 이 법에 의해 정하는 모든 소득에 대해서 과세된다. 다만, 특별히 과세되지 중요 서명 연령부터 국내에 주소한지 튼 기간의 합계가 5년 이상의 외국인 거주자로이에게 과세되는 소득은 국외법에 발생된 소득의 경우 국내에서 지급되는 국민소득에 대해서만 과세한다.\n비과세규정에는 제119조에 따라 한국원천소득에 대해서만 과세한다.\n제18항 및 제2항을 적용하는 경우 "조세특례제한법" 제100조제14제2항에 의거한 제100조제18제1항에 따라 배분받은 소득 및 같은 법 제100조제22제1항에 따라 분배받은 자산 중 분배법인에 지분을 초과하여 발생하는 소득에 대하여 과세한다.\n[전문개정 2009. 12. 31.]\n제40조(소득의 구분)\n\n종합소득\n   이 법에 따라 규정되는 모든 소득에 제2조 및 제3조에 따른 소득으로 제외된 소득으로 다음 각 목의 소득을 포함한 것  \n\n소득세법\n가. 이자소득\n나. 배당소득\n다. 사업소득\n라. 근로소득\n마. 영업소득\n바. 기타소득'),
#   Document(id='0562bdcd-9977-4b3b-8937-a52fae4ac568', metadata={'source': './data/income_tax.txt'}, page_content="소득세법\n가. 이자소득\n나. 배당소득\n다. 사업소득\n라. 근로소득\n마. 영업소득\n바. 기타소득  \n\n퇴직소득\n2의2. 삭제 <2024. 12. 31.>  \n양도소득\n② 제1항에 따른 소득을 규급할 때 다음 각 호의 신탁의 이익은 「신탁법」 제2조에 따른 수탁자에게 이전하거나 그 밖에 처분된 재산권에서 발생하는 소득의 내용별로 구분한다. <개정 2011. 7. 25, 2020. 12. 29, 2022. 12. 31, 2024. 12. 31.>  \n'합성재산' 제305조제2항에 따라 신탁재산에 귀속되는 소득에 대하여 그 신탁의 수탁자가 법인설비를 납부하는 신탁  \n'자본시장과 금융투자업에 관한 법률', 제90조제1항제1호에 따른 투자신탁(제17조제1항제5호에 따른 집합투자기구 포함)한다  \n'자본시장과 금융투자업에 관한 법률', 제251조제1항에 따른 집합투자업영업보험회사의 특별계정  \n제7조제1항제3호의에 따른 수익증권이 발행된 신탁  \n비거주자의 소득은 제19조에 따라 구분한다.\n[전문개정 2009. 12. 31.]")],
#  'answer': AIMessage(content='소득세법에서 정의하는 종합소득의 종류는 이자소득, 배당소득, 사업소득, 근로소득, 영업소득 및 기타소득입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 2821, 'total_tokens': 2864, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_83554c687e', 'id': 'chatcmpl-CnLmeqW3L3Bb7p7baRVaitXtKyKma', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b2685-83f1-71f1-a71b-e00b0efff524-0', usage_metadata={'input_tokens': 2821, 'output_tokens': 43, 'total_tokens': 2864, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}
